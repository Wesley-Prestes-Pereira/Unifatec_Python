# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 3 - Exercicio 6

num=float(input("Digite o valor do produto:"));
if(num>0 and num<=20):
    print("Valor do produto:",num,"\n","Valor do produto com 45%:",((num*0.45)+num),"\nFim do Progrma.");
elif(num>20):
    print("Valor do produto:",num,"\n","Valor do produto com 30%:",((num*0.30)+num),"\nFim do Progrma.");
else:
    print("Valor do produto inferior ou igual a zero.\nFim do Progrma.");
