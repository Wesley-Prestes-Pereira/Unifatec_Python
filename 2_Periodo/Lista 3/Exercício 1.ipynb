# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 3 - Exercicio 1

num=int(input("Digite um número:"));
if(num<20):
    print("Este numero é inferior a 20.\nFim do Progrma.");

elif(num>=20 and num<=90):
    print("Este número está compreendido entre 20 e 90.\nFim do Progrma.");
else:
    print("Este número é superior à 90.\nFim do Progrma.");
