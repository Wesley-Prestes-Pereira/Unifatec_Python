# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 3 - Exercicio 3

num1=int(input("Digite um número:"));
num2=int(input("Digite outro número:"));
if(num1>num2):
    print(num1,"é maior que o número",num2,"\nFim do Progrma.");
elif(num1==num2):
    print("Números iguais.\nFim do Progrma.");
else:
    print(num1,"é menor que o número",num2,"\nFim do Progrma.");
