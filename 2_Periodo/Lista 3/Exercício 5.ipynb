# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 3 - Exercicio 5

idade=int(input("Digite sua idade:"));
if(idade>65):
    print("Sua idade é maior que 65 anos.\nFim do Progrma.");
elif(idade>=18):
    print("Maior de idade.\nFim do Progrma.");
else:
    print("Menor de idade.\nFim do Progrma.");
