# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - noite
# Lista 2 - Exercicio 6
num=int(input("Digite o valor do lado:"));
print("Area do quadrado :",(num*num));
print("Perimetro do quadrado :",(num*4));
