# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - noite
# Lista 2 - Exercicio 7
base=float(input("Digite o valor da base do triangulo:"));
altu=float(input("Digite o valor da altura do tringulo:"));
print("Area do trinagulo :",((base*altu)/2));
