# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - noite
# Lista 2 - Exercicio 2
print("O produto da multiplicação de 28 e 43 é",(28*43));
res=str(input("Deseja realizar outra multiplição: S/N?"));
while True:
    if(res=="S" or res=="s"):
        num1=int(input("Digite o primeiro numero à ser multiplicado:"));
        num2=int(input("Digite o segundo numero à ser multiplicado:"));
        print("O resultado da multiplicação é de:",(num1*num2));
        res=str(input("Deseja realizar outra multiplição: S/N?"));
        if(res=="N" or res=="n"):
            print("Fim do programa.");
            break;
    elif(res=="N" or res=="n"):
        print("Fim do programa.");
        break;
    else:
        print("Digite S para sim e N para não.");
        res=str(input("Deseja realizar outra multiplição: S/N?"));
