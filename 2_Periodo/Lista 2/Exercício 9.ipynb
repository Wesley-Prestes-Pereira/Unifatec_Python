# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - noite
# Lista 2 - Exercicio 9
num=int(input("Digite um numero:"));
if (num%5==0):
    print("Este numero é multiplo de 5.");
else:
    print("Este numero não é multiplo de 5.");
