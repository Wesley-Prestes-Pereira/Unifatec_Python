# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 1 - Exercicio 3
num = int(input("Digite um numero:"))
if ((num%3)==0):
    print("Este numero é múltiplo de 3");
else:
    print("Este numero não é múltiplo de 3");
# Out:
# Digite um numero:6
# Este numero é múltiplo de 3
