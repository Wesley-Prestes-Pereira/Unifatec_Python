# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 1 - Exercicio 6

nome = str(input("Digite seu nome:"));
idade = int(input("Digite sua idade:"));
sexo = str(input("Digite seu sexo:"));
if ((sexo == "m") or (sexo == "M")):
    print("NÃO ACEITO.");
elif ((sexo == "f") or (sexo == "F")):
        if (idade < 25):
             print("ACEITA");
        else:
                 print("NÃO ACEITA.");
else:
      print("Sexo invalido, digite F ou f para feminino e M ou m para masculino.");
      while True:
        sexo = str(input("Digite seu sexo:"));
        if ((sexo == "f") or (sexo == "F")):
            if (idade < 25):
                print("ACEITA.");
                break;
            else:
                print("NÃO ACEITA.");
                break;
        elif((sexo=="m") or (sexo=="M")):
            print("NÃO ACEITO.");
            break;
# Out:
# Digite seu nome:W35l3y
# Digite sua idade:20
# Digite seu sexo:M
# NÃO ACEITO.
