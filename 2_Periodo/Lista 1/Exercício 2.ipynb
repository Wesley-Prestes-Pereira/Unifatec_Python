# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 1 - Exercicio 2
num = int(input("Digite um numero:"))
if (num >= 20):
    print("Este numero é maior ou igual à 20:", num);
else:
    print("Este numero é menor do que 20");
# Out:
# Digite um numero:21
# Este numero é maior ou igual à 20: 21
