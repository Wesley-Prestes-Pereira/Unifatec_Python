# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 1 - Exercicio 4
num = int(input("Digite um numero:"))
if (((num%3)==0)and((num%7)==0)):
    print("Este numero é divisivel por 3 e por 7");
else:
    print("Este numero não é divisivel por 3 e por 7");
# Out:
# Digite um numero:21
# Este numero é divisivel por 3 e por 7
