# %%
# Wesley Prestes Pereira
# Engenharia da computação - 2º periodo - Noite
# Lista 1 - Exercicio 5
ano=int(input("Digite o ano atual:"));
idade = int(input("Digite seu ano de nascimento:"));
if (((idade>0)and(idade<ano))or((ano-idade)>=0)):
    print("Sua idade é de",(ano-idade),"anos");
else:
    print("Ano invalido");
# Out:
# Digite o ano atual:2024
# Digite seu ano de nascimento:2025
# Ano invalido
